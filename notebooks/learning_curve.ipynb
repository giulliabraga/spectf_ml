# %%
import pandas as pd
import sys
import os
sys.path.append(os.path.abspath('../modules'))
from plot_learning_curve import LearningCurvePlotter
import warnings 
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv('../data/preprocessed/SPECTF_preprocessed.csv')

# Get the features and target variable
X = dataset.drop(columns='target')
y = dataset['target']

# %%
plotter = LearningCurvePlotter(X, y)
plotter.plot_learning_curve()

# %%
results_df = plotter.get_results()
results_df
# Out:
#    train_size  test_accuracy  error_rate  coverage  f1_score
# 0        5.0%       0.716049    0.283951  0.859375  0.696908
# 1       10.0%       0.740741    0.259259  0.937500  0.672445
# 2       15.0%       0.567901    0.432099  0.546875  0.607754
# 3       20.0%       0.790123    0.209877  0.968750  0.734837
# 4       25.0%       0.666667    0.333333  0.703125  0.691738
# 5       30.0%       0.320988    0.679012  0.250000  0.346587
# 6       35.0%       0.790123    0.209877  1.000000  0.697488
# 7       40.0%       0.790123    0.209877  1.000000  0.697488
# 8       45.0%       0.790123    0.209877  1.000000  0.697488
# 9       50.0%       0.790123    0.209877  1.000000  0.697488
# 10      55.0%       0.790123    0.209877  1.000000  0.697488
# 11      60.0%       0.790123    0.209877  1.000000  0.697488
# 12      65.0%       0.790123    0.209877  1.000000  0.697488
# 13      70.0%       0.790123    0.209877  1.000000  0.697488
# ...
