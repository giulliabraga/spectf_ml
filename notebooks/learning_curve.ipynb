# %%
import pandas as pd
import sys
import os
sys.path.append(os.path.abspath('../modules'))
from plot_learning_curve import LearningCurvePlotter

# %%
dataset = pd.read_csv('../data/preprocessed/SPECTF_preprocessed.csv')

# Get the features and target variable
X = dataset.drop(columns='target')
y = dataset['target']

# %%
plotter = LearningCurvePlotter(X, y)
plotter.plot_learning_curve()

# %%
results_df = plotter.get_results()
results_df
# Out:
#    train_size  test_accuracy  error_rate  coverage  f1_score
# 0        5.0%       0.787402    0.212598       1.0  0.700683
# 1       10.0%       0.804979    0.195021       1.0  0.793618
# 2       15.0%       0.718062    0.281938       1.0  0.744619
# 3       20.0%       0.780374    0.219626       1.0  0.796683
# 4       25.0%       0.701493    0.298507       1.0  0.730073
# 5       30.0%       0.748663    0.251337       1.0  0.769703
# 6       35.0%       0.718391    0.281609       1.0  0.745117
# 7       40.0%       0.677019    0.322981       1.0  0.708098
# 8       45.0%       0.687075    0.312925       1.0  0.717069
# 9       50.0%       0.716418    0.283582       1.0  0.742105
# 10      55.0%       0.702479    0.297521       1.0  0.730680
# 11      60.0%       0.691589    0.308411       1.0  0.720873
# 12      65.0%       0.712766    0.287234       1.0  0.737455
# 13      70.0%       0.716049    0.283951       1.0  0.742394
# 14      75.0%       0.686567    0.313433       1.0  0.715837
# 15      80.0%       0.759259    0.240741       1.0  0.780136
# 16      85.0%       0.756098    0.243902       1.0  0.779927
# 17      90.0%       0.518519    0.481481       1.0  0.548231
# 18      95.0%       0.785714    0.214286       1.0  0.804511
