# %% [markdown]
# # Statistical comparison of multiple classifiers
#
# Here, multiple classifiers were compared by using the results of a 30 x 10-fold cross-validation.
#
# They are compared when finetuning was employed or not.

# %%
import pandas as pd
import sys
import os
sys.path.append(os.path.abspath('../modules'))
from statistical_methods import StatisticalMethods

# %% [markdown]
# ## No finetuning

# %%
finetune = False

# %%
knn_results = pd.read_csv(f'../results/metrics_KNN_tuning_{finetune}.csv')
gnb_results = pd.read_csv(f'../results/metrics_GNB_tuning_{finetune}.csv')
lr_results = pd.read_csv(f'../results/metrics_LR_tuning_{finetune}.csv')
parzen_results = pd.read_csv(f'../results/metrics_Parzen_tuning_{finetune}.csv')
voting_results = pd.read_csv(f'../results/metrics_VotingClassifier_tuning_{finetune}.csv')

list_of_model_results = [knn_results, gnb_results, lr_results, parzen_results, voting_results]
list_of_model_names = ['KNN', 'GNB', 'LR', 'Parzen', 'VotingClassifier']
list_of_metrics_names = ['error_rate', 'test_accuracy', 'coverage', 'f1_score']

comp = StatisticalMethods(list_of_model_results, list_of_model_names, list_of_metrics_names)

friedman_results, metrics_with_difference = comp.friedman_test()

nemenyi_results = comp.nemenyi_test(metrics_with_difference)

# %%
comp.get_estimate_and_ci()
# Out:
#                model         metric      mean       std              ci
# 0                KNN     error_rate  0.255076  0.069403  0.2472, 0.2629
# 1                KNN  test_accuracy  0.744924  0.069403  0.7371, 0.7528
# 2                KNN       coverage  0.814430  0.069313  0.8066, 0.8223
# 3                KNN       f1_score  0.840360  0.046899  0.8351, 0.8457
# 4                GNB     error_rate  0.316515  0.083352  0.3071, 0.3259
# 5                GNB  test_accuracy  0.683485  0.083352  0.6741, 0.6929
# 6                GNB       coverage  0.519611  0.086643  0.5098, 0.5294
# 7                GNB       f1_score  0.754490  0.079124  0.7455, 0.7634
# 8                 LR     error_rate  0.244131  0.074624  0.2357, 0.2526
# 9                 LR  test_accuracy  0.755869  0.074624  0.7474, 0.7643
# 10                LR       coverage  0.810997  0.078313  0.8021, 0.8199
# 11                LR       f1_score  0.846458  0.051537  0.8406, 0.8523
# 12            Parzen     error_rate  0.056220  0.050255  0.0505, 0.0619
# 13            Parzen  test_accuracy  0.943780  0.050255  0.9381, 0.9495
# 14            Parzen       coverage  0.745413  0.049003  0.7399, 0.7510
# 15            Parzen       f1_score  0.962484  0.037989  0.9582, 0.9668
# 16  VotingClassifier     error_rate  0.297840  0.088889  0.2878, 0.3079
# 17  VotingClassifier  test_accuracy  0.702160  0.088889  0.6921, 0.7122
# 18  VotingClassifier       coverage  0.618865  0.090647  0.6086, 0.6291
# 19  VotingClassifier       f1_score  0.785902  0.072201  0.7777, 0.7941

# %%
formatted_stats = comp.get_formatted_estimate_and_ci()
formatted_stats
# Out:
#               Modelo            Métrica     Média (%)           IC (%)
# 0                KNN       Taxa de erro  25.51 ± 6.94  [24.72 , 26.29]
# 1                KNN  Acurácia de teste  74.49 ± 6.94  [73.71 , 75.28]
# 2                KNN          Cobertura  81.44 ± 6.93  [80.66 , 82.23]
# 3                KNN           F1-score  84.04 ± 4.69  [83.51 , 84.57]
# 4                GNB       Taxa de erro  31.65 ± 8.34  [30.71 , 32.59]
# 5                GNB  Acurácia de teste  68.35 ± 8.34  [67.41 , 69.29]
# 6                GNB          Cobertura  51.96 ± 8.66  [50.98 , 52.94]
# 7                GNB           F1-score  75.45 ± 7.91  [74.55 , 76.34]
# 8                 LR       Taxa de erro  24.41 ± 7.46  [23.57 , 25.26]
# 9                 LR  Acurácia de teste  75.59 ± 7.46  [74.74 , 76.43]
# 10                LR          Cobertura  81.10 ± 7.83  [80.21 , 81.99]
# 11                LR           F1-score  84.65 ± 5.15  [84.06 , 85.23]
# 12            Parzen       Taxa de erro   5.62 ± 5.03    [5.05 , 6.19]
# 13            Parzen  Acurácia de teste  94.38 ± 5.03  [93.81 , 94.95]
# 14            Parzen          Cobertura  74.54 ± 4.90  [73.99 , 75.10]
# 15            Parzen           F1-score  96.25 ± 3.80  [95.82 , 96.68]
# 16  VotingClassifier       Taxa de erro  29.78 ± 8.89  [28.78 , 30.79]
# 17  VotingClassifier  Acurácia de teste  70.22 ± 8.89  [69.21 , 71.22]
# 18  VotingClassifier          Cobertura  61.89 ± 9.06  [60.86 , 62.91]
# 19  VotingClassifier           F1-score  78.59 ± 7.22  [77.77 , 79.41]

# %%
friedman_results
# Out:
#           metric   statistic        p-value  are_different
# 0     error_rate  715.487522  1.543985e-153           True
# 1  test_accuracy  715.487522  1.543985e-153           True
# 2       coverage  955.145551  1.873816e-205           True
# 3       f1_score  792.133692  3.883453e-170           True

# %%
nemenyi_results
# Out:
#            metric             classifier_pair       p-value  are_different
# 0      error_rate                  KNN vs GNB  7.728262e-13           True
# 1      error_rate                   KNN vs LR  7.658616e-01          False
# 2      error_rate               KNN vs Parzen  1.110223e-16           True
# 3      error_rate     KNN vs VotingClassifier  4.961026e-08           True
# 4      error_rate                   GNB vs LR  1.110223e-16           True
# 5      error_rate               GNB vs Parzen  1.110223e-16           True
# 6      error_rate     GNB vs VotingClassifier  4.801892e-01          False
# 7      error_rate                LR vs Parzen  1.110223e-16           True
# 8      error_rate      LR vs VotingClassifier  2.171163e-11           True
# 9      error_rate  Parzen vs VotingClassifier  1.110223e-16           True
# 10  test_accuracy                  KNN vs GNB  7.728262e-13           True
# 11  test_accuracy                   KNN vs LR  7.658616e-01          False
# 12  test_accuracy               KNN vs Parzen  1.110223e-16           True
# 13  test_accuracy     KNN vs VotingClassifier  4.961026e-08           True
# 14  test_accuracy                   GNB vs LR  1.110223e-16           True
# 15  test_accuracy               GNB vs Parzen  1.110223e-16           True
# 16  test_accuracy     GNB vs VotingClassifier  4.801892e-01          False
# 17  test_accuracy                LR vs Parzen  1.110223e-16           True
# 18  test_accuracy      LR vs VotingClassifier  2.171163e-11           True
# 19  test_accuracy  Parzen vs VotingClassifier  1.110223e-16           True
# 20       coverage                  KNN vs GNB  1.110223e-16           True
# 21       coverage                   KNN vs LR  9.720026e-01          False
# 22       coverage               KNN vs Parzen  2.873257e-13           True
# 23       coverage     KNN vs VotingClassifier  1.110223e-16           True
# 24       coverage                   GNB vs LR  1.110223e-16           True
# 25       coverage               GNB vs Parzen  1.110223e-16           True
# 26       coverage     GNB vs VotingClassifier  1.220618e-10           True
# 27       coverage                LR vs Parzen  2.862854e-11           True
# 28       coverage      LR vs VotingClassifier  1.110223e-16           True
# 29       coverage  Parzen vs VotingClassifier  1.110223e-16           True
# 30       f1_score                  KNN vs GNB  1.110223e-16           True
# 31       f1_score                   KNN vs LR  9.571732e-01          False
# 32       f1_score               KNN vs Parzen  1.110223e-16           True
# 33       f1_score     KNN vs VotingClassifier  2.220446e-16           True
# 34       f1_score                   GNB vs LR  1.110223e-16           True
# 35       f1_score               GNB vs Parzen  1.110223e-16           True
# 36       f1_score     GNB vs VotingClassifier  3.135838e-02           True
# 37       f1_score                LR vs Parzen  1.110223e-16           True
# 38       f1_score      LR vs VotingClassifier  1.110223e-16           True
# 39       f1_score  Parzen vs VotingClassifier  1.110223e-16           True

# %%
nemenyi_results.loc[nemenyi_results['are_different'] == False]
# Out:
#            metric          classifier_pair   p-value  are_different
# 1      error_rate                KNN vs LR  0.765862          False
# 6      error_rate  GNB vs VotingClassifier  0.480189          False
# 11  test_accuracy                KNN vs LR  0.765862          False
# 16  test_accuracy  GNB vs VotingClassifier  0.480189          False
# 21       coverage                KNN vs LR  0.972003          False
# 31       f1_score                KNN vs LR  0.957173          False

# %% [markdown]
# ## With finetuning

# %%
finetune = True

# %%
knn_results = pd.read_csv(f'../results/metrics_KNN_tuning_{finetune}.csv')
gnb_results = pd.read_csv(f'../results/metrics_GNB_tuning_{finetune}.csv')
lr_results = pd.read_csv(f'../results/metrics_LR_tuning_{finetune}.csv')
parzen_results = pd.read_csv(f'../results/metrics_Parzen_tuning_{finetune}.csv')
voting_results = pd.read_csv(f'../results/metrics_VotingClassifier_tuning_{finetune}.csv')

list_of_model_results = [knn_results, gnb_results, lr_results, parzen_results, voting_results]
list_of_model_names = ['KNN', 'GNB', 'LR', 'Parzen', 'VotingClassifier']
list_of_metrics_names = ['error_rate', 'test_accuracy', 'coverage', 'f1_score']

comp = StatisticalMethods(list_of_model_results, list_of_model_names, list_of_metrics_names)

friedman_results, metrics_with_difference = comp.friedman_test()

nemenyi_results = comp.nemenyi_test(metrics_with_difference)

# %%
comp.get_estimate_and_ci()
# Out:
#                model         metric      mean       std              ci
# 0                KNN     error_rate  0.242996  0.074137  0.2346, 0.2514
# 1                KNN  test_accuracy  0.757004  0.074137  0.7486, 0.7654
# 2                KNN       coverage  0.773167  0.080522  0.7641, 0.7823
# 3                KNN       f1_score  0.843606  0.051710  0.8378, 0.8495
# 4                GNB     error_rate  0.316515  0.083243  0.3071, 0.3259
# 5                GNB  test_accuracy  0.683485  0.083243  0.6741, 0.6929
# 6                GNB       coverage  0.519364  0.087015  0.5095, 0.5292
# 7                GNB       f1_score  0.754412  0.079170  0.7455, 0.7634
# 8                 LR     error_rate  0.200760  0.069639  0.1929, 0.2086
# 9                 LR  test_accuracy  0.799240  0.069639  0.7914, 0.8071
# 10                LR       coverage  0.802678  0.070583  0.7947, 0.8107
# 11                LR       f1_score  0.873350  0.046375  0.8681, 0.8786
# 12            Parzen     error_rate  0.314796  0.087983  0.3048, 0.3248
# 13            Parzen  test_accuracy  0.685204  0.087983  0.6752, 0.6952
# 14            Parzen       coverage  0.647417  0.090048  0.6372, 0.6576
# 15            Parzen       f1_score  0.778559  0.071224  0.7705, 0.7866
# 16  VotingClassifier     error_rate  0.267441  0.083753  0.2580, 0.2769
# 17  VotingClassifier  test_accuracy  0.732559  0.083753  0.7231, 0.7420
# 18  VotingClassifier       coverage  0.613272  0.083357  0.6038, 0.6227
# 19  VotingClassifier       f1_score  0.806942  0.068341  0.7992, 0.8147

# %%
formatted_stats = comp.get_formatted_estimate_and_ci()
formatted_stats
# Out:
#               Modelo            Métrica     Média (%)           IC (%)
# 0                KNN       Taxa de erro  24.30 ± 7.41  [23.46 , 25.14]
# 1                KNN  Acurácia de teste  75.70 ± 7.41  [74.86 , 76.54]
# 2                KNN          Cobertura  77.32 ± 8.05  [76.41 , 78.23]
# 3                KNN           F1-score  84.36 ± 5.17  [83.78 , 84.95]
# 4                GNB       Taxa de erro  31.65 ± 8.32  [30.71 , 32.59]
# 5                GNB  Acurácia de teste  68.35 ± 8.32  [67.41 , 69.29]
# 6                GNB          Cobertura  51.94 ± 8.70  [50.95 , 52.92]
# 7                GNB           F1-score  75.44 ± 7.92  [74.55 , 76.34]
# 8                 LR       Taxa de erro  20.08 ± 6.96  [19.29 , 20.86]
# 9                 LR  Acurácia de teste  79.92 ± 6.96  [79.14 , 80.71]
# 10                LR          Cobertura  80.27 ± 7.06  [79.47 , 81.07]
# 11                LR           F1-score  87.34 ± 4.64  [86.81 , 87.86]
# 12            Parzen       Taxa de erro  31.48 ± 8.80  [30.48 , 32.48]
# 13            Parzen  Acurácia de teste  68.52 ± 8.80  [67.52 , 69.52]
# 14            Parzen          Cobertura  64.74 ± 9.00  [63.72 , 65.76]
# 15            Parzen           F1-score  77.86 ± 7.12  [77.05 , 78.66]
# 16  VotingClassifier       Taxa de erro  26.74 ± 8.38  [25.80 , 27.69]
# 17  VotingClassifier  Acurácia de teste  73.26 ± 8.38  [72.31 , 74.20]
# 18  VotingClassifier          Cobertura  61.33 ± 8.34  [60.38 , 62.27]
# 19  VotingClassifier           F1-score  80.69 ± 6.83  [79.92 , 81.47]

# %%
friedman_results
# Out:
#           metric   statistic        p-value  are_different
# 0     error_rate  433.728972   1.429344e-92           True
# 1  test_accuracy  433.728972   1.429344e-92           True
# 2       coverage  995.156083  4.002537e-214           True
# 3       f1_score  570.172798  4.416185e-122           True

# %%
nemenyi_results
# Out:
#            metric             classifier_pair       p-value  are_different
# 0      error_rate                  KNN vs GNB  1.110223e-16           True
# 1      error_rate                   KNN vs LR  1.933307e-08           True
# 2      error_rate               KNN vs Parzen  1.110223e-16           True
# 3      error_rate     KNN vs VotingClassifier  1.114551e-01          False
# 4      error_rate                   GNB vs LR  1.110223e-16           True
# 5      error_rate               GNB vs Parzen  9.992025e-01          False
# 6      error_rate     GNB vs VotingClassifier  2.886580e-15           True
# 7      error_rate                LR vs Parzen  1.110223e-16           True
# 8      error_rate      LR vs VotingClassifier  5.551115e-16           True
# 9      error_rate  Parzen vs VotingClassifier  2.042810e-14           True
# 10  test_accuracy                  KNN vs GNB  1.110223e-16           True
# 11  test_accuracy                   KNN vs LR  1.933307e-08           True
# 12  test_accuracy               KNN vs Parzen  1.110223e-16           True
# 13  test_accuracy     KNN vs VotingClassifier  1.114551e-01          False
# 14  test_accuracy                   GNB vs LR  1.110223e-16           True
# 15  test_accuracy               GNB vs Parzen  9.992025e-01          False
# 16  test_accuracy     GNB vs VotingClassifier  2.886580e-15           True
# 17  test_accuracy                LR vs Parzen  1.110223e-16           True
# 18  test_accuracy      LR vs VotingClassifier  5.551115e-16           True
# 19  test_accuracy  Parzen vs VotingClassifier  2.042810e-14           True
# 20       coverage                  KNN vs GNB  1.110223e-16           True
# 21       coverage                   KNN vs LR  8.674354e-02          False
# 22       coverage               KNN vs Parzen  1.110223e-16           True
# 23       coverage     KNN vs VotingClassifier  1.110223e-16           True
# 24       coverage                   GNB vs LR  1.110223e-16           True
# 25       coverage               GNB vs Parzen  1.110223e-16           True
# 26       coverage     GNB vs VotingClassifier  7.771561e-16           True
# 27       coverage                LR vs Parzen  1.110223e-16           True
# 28       coverage      LR vs VotingClassifier  1.110223e-16           True
# 29       coverage  Parzen vs VotingClassifier  4.106322e-04           True
# 30       f1_score                  KNN vs GNB  1.110223e-16           True
# 31       f1_score                   KNN vs LR  5.865287e-07           True
# 32       f1_score               KNN vs Parzen  1.110223e-16           True
# 33       f1_score     KNN vs VotingClassifier  5.791471e-08           True
# 34       f1_score                   GNB vs LR  1.110223e-16           True
# 35       f1_score               GNB vs Parzen  2.918171e-03           True
# 36       f1_score     GNB vs VotingClassifier  1.110223e-16           True
# 37       f1_score                LR vs Parzen  1.110223e-16           True
# 38       f1_score      LR vs VotingClassifier  1.110223e-16           True
# 39       f1_score  Parzen vs VotingClassifier  6.756505e-08           True

# %%
nemenyi_results.loc[nemenyi_results['are_different'] == False]
# Out:
#            metric          classifier_pair   p-value  are_different
# 3      error_rate  KNN vs VotingClassifier  0.111455          False
# 5      error_rate            GNB vs Parzen  0.999203          False
# 13  test_accuracy  KNN vs VotingClassifier  0.111455          False
# 15  test_accuracy            GNB vs Parzen  0.999203          False
# 21       coverage                KNN vs LR  0.086744          False
