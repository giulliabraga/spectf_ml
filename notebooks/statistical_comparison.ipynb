# %% [markdown]
# # Statistical comparison of multiple classifiers
#
# Here, multiple classifiers were compared by using the results of a 30 x 10-fold cross-validation.
#
# They are compared when finetuning was employed or not.

# %%
import pandas as pd
import sys
import os
sys.path.append(os.path.abspath('../modules'))
from statistical_methods import StatisticalMethods

# %% [markdown]
# ## No finetuning

# %%
finetune = False

# %%
knn_results = pd.read_csv(f'../results/metrics_KNN_tuning_{finetune}.csv')
qda_results = pd.read_csv(f'../results/metrics_QDA_tuning_{finetune}.csv')
lr_results = pd.read_csv(f'../results/metrics_LR_tuning_{finetune}.csv')
parzen_results = pd.read_csv(f'../results/metrics_Parzen_tuning_{finetune}.csv')
voting_results = pd.read_csv(f'../results/metrics_Voting_tuning_{finetune}.csv')

list_of_model_results = [knn_results, qda_results, lr_results, parzen_results, voting_results]
list_of_model_names = ['KNN', 'QDA', 'LR', 'Parzen', 'Voting']
list_of_metrics_names = ['error_rate', 'test_accuracy', 'coverage', 'f1_score']

comp = StatisticalMethods(list_of_model_results, list_of_model_names, list_of_metrics_names)

friedman_results, metrics_with_difference = comp.friedman_test()

nemenyi_results = comp.nemenyi_test(metrics_with_difference)

# %%
comp.get_estimate_and_ci()
# Out:
#      model         metric      mean       std              ci
# 0      KNN     error_rate  0.255076  0.069403  0.2472, 0.2629
# 1      KNN  test_accuracy  0.744924  0.069403  0.7371, 0.7528
# 2      KNN       coverage  0.814430  0.069313  0.8066, 0.8223
# 3      KNN       f1_score  0.840360  0.046899  0.8351, 0.8457
# 4      QDA     error_rate  0.206087  0.016807  0.2042, 0.2080
# 5      QDA  test_accuracy  0.793913  0.016807  0.7920, 0.7958
# 6      QDA       coverage  0.999753  0.003014  0.9994, 1.0001
# 7      QDA       f1_score  0.885021  0.010447  0.8838, 0.8862
# 8       LR     error_rate  0.244131  0.074624  0.2357, 0.2526
# 9       LR  test_accuracy  0.755869  0.074624  0.7474, 0.7643
# 10      LR       coverage  0.810997  0.078313  0.8021, 0.8199
# 11      LR       f1_score  0.846458  0.051537  0.8406, 0.8523
# 12  Parzen     error_rate  0.056220  0.050255  0.0505, 0.0619
# 13  Parzen  test_accuracy  0.943780  0.050255  0.9381, 0.9495
# 14  Parzen       coverage  0.745413  0.049003  0.7399, 0.7510
# 15  Parzen       f1_score  0.962484  0.037989  0.9582, 0.9668
# 16  Voting     error_rate  0.277422  0.074415  0.2690, 0.2858
# 17  Voting  test_accuracy  0.722578  0.074415  0.7142, 0.7310
# 18  Voting       coverage  0.767564  0.082579  0.7582, 0.7769
# 19  Voting       f1_score  0.820729  0.052985  0.8147, 0.8267

# %%
formatted_stats = comp.get_formatted_estimate_and_ci()
formatted_stats
# Out:
#     Modelo            Métrica     Média (%)            IC (%)
# 0      KNN       Taxa de erro  25.51 ± 6.94   [24.72 , 26.29]
# 1      KNN  Acurácia de teste  74.49 ± 6.94   [73.71 , 75.28]
# 2      KNN          Cobertura  81.44 ± 6.93   [80.66 , 82.23]
# 3      KNN           F1-score  84.04 ± 4.69   [83.51 , 84.57]
# 4      QDA       Taxa de erro  20.61 ± 1.68   [20.42 , 20.80]
# 5      QDA  Acurácia de teste  79.39 ± 1.68   [79.20 , 79.58]
# 6      QDA          Cobertura  99.98 ± 0.30  [99.94 , 100.01]
# 7      QDA           F1-score  88.50 ± 1.04   [88.38 , 88.62]
# 8       LR       Taxa de erro  24.41 ± 7.46   [23.57 , 25.26]
# 9       LR  Acurácia de teste  75.59 ± 7.46   [74.74 , 76.43]
# 10      LR          Cobertura  81.10 ± 7.83   [80.21 , 81.99]
# 11      LR           F1-score  84.65 ± 5.15   [84.06 , 85.23]
# 12  Parzen       Taxa de erro   5.62 ± 5.03     [5.05 , 6.19]
# 13  Parzen  Acurácia de teste  94.38 ± 5.03   [93.81 , 94.95]
# 14  Parzen          Cobertura  74.54 ± 4.90   [73.99 , 75.10]
# 15  Parzen           F1-score  96.25 ± 3.80   [95.82 , 96.68]
# 16  Voting       Taxa de erro  27.74 ± 7.44   [26.90 , 28.58]
# 17  Voting  Acurácia de teste  72.26 ± 7.44   [71.42 , 73.10]
# 18  Voting          Cobertura  76.76 ± 8.26   [75.82 , 77.69]
# 19  Voting           F1-score  82.07 ± 5.30   [81.47 , 82.67]

# %%
friedman_results
# Out:
#           metric   statistic        p-value  are_different
# 0     error_rate  739.759740  8.559467e-159           True
# 1  test_accuracy  739.759740  8.559467e-159           True
# 2       coverage  769.612836  2.931336e-165           True
# 3       f1_score  770.785291  1.633539e-165           True

# %%
nemenyi_results
# Out:
#            metric   classifier_pair       p-value  are_different
# 0      error_rate        KNN vs QDA  2.481118e-10           True
# 1      error_rate         KNN vs LR  2.978887e-01          False
# 2      error_rate     KNN vs Parzen  1.110223e-16           True
# 3      error_rate     KNN vs Voting  1.073016e-03           True
# 4      error_rate         QDA vs LR  2.130006e-05           True
# 5      error_rate     QDA vs Parzen  1.110223e-16           True
# 6      error_rate     QDA vs Voting  1.110223e-16           True
# 7      error_rate      LR vs Parzen  1.110223e-16           True
# 8      error_rate      LR vs Voting  6.756505e-08           True
# 9      error_rate  Parzen vs Voting  1.110223e-16           True
# 10  test_accuracy        KNN vs QDA  2.481118e-10           True
# 11  test_accuracy         KNN vs LR  2.978887e-01          False
# 12  test_accuracy     KNN vs Parzen  1.110223e-16           True
# 13  test_accuracy     KNN vs Voting  1.073016e-03           True
# 14  test_accuracy         QDA vs LR  2.130006e-05           True
# 15  test_accuracy     QDA vs Parzen  1.110223e-16           True
# 16  test_accuracy     QDA vs Voting  1.110223e-16           True
# 17  test_accuracy      LR vs Parzen  1.110223e-16           True
# 18  test_accuracy      LR vs Voting  6.756505e-08           True
# 19  test_accuracy  Parzen vs Voting  1.110223e-16           True
# 20       coverage        KNN vs QDA  1.110223e-16           True
# 21       coverage         KNN vs LR  8.402234e-01          False
# 22       coverage     KNN vs Parzen  1.110223e-16           True
# 23       coverage     KNN vs Voting  1.221245e-14           True
# 24       coverage         QDA vs LR  1.110223e-16           True
# 25       coverage     QDA vs Parzen  1.110223e-16           True
# 26       coverage     QDA vs Voting  1.110223e-16           True
# 27       coverage      LR vs Parzen  6.661338e-16           True
# 28       coverage      LR vs Voting  3.138312e-11           True
# 29       coverage  Parzen vs Voting  6.146309e-01          False
# 30       f1_score        KNN vs QDA  1.110223e-16           True
# 31       f1_score         KNN vs LR  4.801892e-01          False
# 32       f1_score     KNN vs Parzen  1.110223e-16           True
# 33       f1_score     KNN vs Voting  3.382850e-06           True
# 34       f1_score         QDA vs LR  2.046030e-12           True
# 35       f1_score     QDA vs Parzen  1.110223e-16           True
# 36       f1_score     QDA vs Voting  1.110223e-16           True
# 37       f1_score      LR vs Parzen  1.110223e-16           True
# 38       f1_score      LR vs Voting  1.742536e-10           True
# 39       f1_score  Parzen vs Voting  1.110223e-16           True

# %%
nemenyi_results.loc[nemenyi_results['are_different'] == False]
# Out:
#            metric   classifier_pair   p-value  are_different
# 1      error_rate         KNN vs LR  0.297889          False
# 11  test_accuracy         KNN vs LR  0.297889          False
# 21       coverage         KNN vs LR  0.840223          False
# 29       coverage  Parzen vs Voting  0.614631          False
# 31       f1_score         KNN vs LR  0.480189          False

# %% [markdown]
# ## With finetuning

# %%
finetune = True

# %%
knn_results = pd.read_csv(f'../results/metrics_KNN_tuning_{finetune}.csv')
qda_results = pd.read_csv(f'../results/metrics_QDA_tuning_{finetune}.csv')
lr_results = pd.read_csv(f'../results/metrics_LR_tuning_{finetune}.csv')
parzen_results = pd.read_csv(f'../results/metrics_Parzen_tuning_{finetune}.csv')
voting_results = pd.read_csv(f'../results/metrics_Voting_tuning_{finetune}.csv')

list_of_model_results = [knn_results, qda_results, lr_results, parzen_results, voting_results]
list_of_model_names = ['KNN', 'QDA', 'LR', 'Parzen', 'Voting']
list_of_metrics_names = ['error_rate', 'test_accuracy', 'coverage', 'f1_score']

comp = StatisticalMethods(list_of_model_results, list_of_model_names, list_of_metrics_names)

friedman_results, metrics_with_difference = comp.friedman_test()

nemenyi_results = comp.nemenyi_test(metrics_with_difference)

# %%
comp.get_estimate_and_ci()
# Out:
#      model         metric      mean       std              ci
# 0      KNN     error_rate  0.242996  0.074137  0.2346, 0.2514
# 1      KNN  test_accuracy  0.757004  0.074137  0.7486, 0.7654
# 2      KNN       coverage  0.773167  0.080522  0.7641, 0.7823
# 3      KNN       f1_score  0.843606  0.051710  0.8378, 0.8495
# 4      QDA     error_rate  0.219891  0.046667  0.2146, 0.2252
# 5      QDA  test_accuracy  0.780109  0.046667  0.7748, 0.7854
# 6      QDA       coverage  0.939207  0.145701  0.9227, 0.9557
# 7      QDA       f1_score  0.869852  0.044578  0.8648, 0.8749
# 8       LR     error_rate  0.200745  0.070005  0.1928, 0.2087
# 9       LR  test_accuracy  0.799255  0.070005  0.7913, 0.8072
# 10      LR       coverage  0.804202  0.072600  0.7960, 0.8124
# 11      LR       f1_score  0.873429  0.046706  0.8681, 0.8787
# 12  Parzen     error_rate  0.314796  0.087983  0.3048, 0.3248
# 13  Parzen  test_accuracy  0.685204  0.087983  0.6752, 0.6952
# 14  Parzen       coverage  0.647417  0.090048  0.6372, 0.6576
# 15  Parzen       f1_score  0.778559  0.071224  0.7705, 0.7866
# 16  Voting     error_rate  0.247051  0.083056  0.2377, 0.2564
# 17  Voting  test_accuracy  0.752949  0.083056  0.7436, 0.7623
# 18  Voting       coverage  0.681363  0.090272  0.6711, 0.6916
# 19  Voting       f1_score  0.830056  0.062728  0.8230, 0.8372

# %%
formatted_stats = comp.get_formatted_estimate_and_ci()
formatted_stats
# Out:
#     Modelo            Métrica      Média (%)           IC (%)
# 0      KNN       Taxa de erro   24.30 ± 7.41  [23.46 , 25.14]
# 1      KNN  Acurácia de teste   75.70 ± 7.41  [74.86 , 76.54]
# 2      KNN          Cobertura   77.32 ± 8.05  [76.41 , 78.23]
# 3      KNN           F1-score   84.36 ± 5.17  [83.78 , 84.95]
# 4      QDA       Taxa de erro   21.99 ± 4.67  [21.46 , 22.52]
# 5      QDA  Acurácia de teste   78.01 ± 4.67  [77.48 , 78.54]
# 6      QDA          Cobertura  93.92 ± 14.57  [92.27 , 95.57]
# 7      QDA           F1-score   86.99 ± 4.46  [86.48 , 87.49]
# 8       LR       Taxa de erro   20.07 ± 7.00  [19.28 , 20.87]
# 9       LR  Acurácia de teste   79.93 ± 7.00  [79.13 , 80.72]
# 10      LR          Cobertura   80.42 ± 7.26  [79.60 , 81.24]
# 11      LR           F1-score   87.34 ± 4.67  [86.81 , 87.87]
# 12  Parzen       Taxa de erro   31.48 ± 8.80  [30.48 , 32.48]
# 13  Parzen  Acurácia de teste   68.52 ± 8.80  [67.52 , 69.52]
# 14  Parzen          Cobertura   64.74 ± 9.00  [63.72 , 65.76]
# 15  Parzen           F1-score   77.86 ± 7.12  [77.05 , 78.66]
# 16  Voting       Taxa de erro   24.71 ± 8.31  [23.77 , 25.64]
# 17  Voting  Acurácia de teste   75.29 ± 8.31  [74.36 , 76.23]
# 18  Voting          Cobertura   68.14 ± 9.03  [67.11 , 69.16]
# 19  Voting           F1-score   83.01 ± 6.27  [82.30 , 83.72]

# %%
friedman_results
# Out:
#           metric   statistic        p-value  are_different
# 0     error_rate  350.498246   1.368989e-74           True
# 1  test_accuracy  350.498246   1.368989e-74           True
# 2       coverage  716.628532  8.741097e-154           True
# 3       f1_score  435.271192   6.634106e-93           True

# %%
nemenyi_results
# Out:
#            metric   classifier_pair       p-value  are_different
# 0      error_rate        KNN vs QDA  1.614752e-03           True
# 1      error_rate         KNN vs LR  1.132272e-11           True
# 2      error_rate     KNN vs Parzen  1.110223e-16           True
# 3      error_rate     KNN vs Voting  9.141310e-01          False
# 4      error_rate         QDA vs LR  7.062893e-03           True
# 5      error_rate     QDA vs Parzen  1.110223e-16           True
# 6      error_rate     QDA vs Voting  3.981494e-05           True
# 7      error_rate      LR vs Parzen  1.110223e-16           True
# 8      error_rate      LR vs Voting  1.654232e-14           True
# 9      error_rate  Parzen vs Voting  1.110223e-16           True
# 10  test_accuracy        KNN vs QDA  1.614752e-03           True
# 11  test_accuracy         KNN vs LR  1.132272e-11           True
# 12  test_accuracy     KNN vs Parzen  1.110223e-16           True
# 13  test_accuracy     KNN vs Voting  9.141310e-01          False
# 14  test_accuracy         QDA vs LR  7.062893e-03           True
# 15  test_accuracy     QDA vs Parzen  1.110223e-16           True
# 16  test_accuracy     QDA vs Voting  3.981494e-05           True
# 17  test_accuracy      LR vs Parzen  1.110223e-16           True
# 18  test_accuracy      LR vs Voting  1.654232e-14           True
# 19  test_accuracy  Parzen vs Voting  1.110223e-16           True
# 20       coverage        KNN vs QDA  1.110223e-16           True
# 21       coverage         KNN vs LR  1.004640e-02           True
# 22       coverage     KNN vs Parzen  1.110223e-16           True
# 23       coverage     KNN vs Voting  1.110223e-16           True
# 24       coverage         QDA vs LR  8.658264e-09           True
# 25       coverage     QDA vs Parzen  1.110223e-16           True
# 26       coverage     QDA vs Voting  1.110223e-16           True
# 27       coverage      LR vs Parzen  1.110223e-16           True
# 28       coverage      LR vs Voting  1.110223e-16           True
# 29       coverage  Parzen vs Voting  2.978887e-01          False
# 30       f1_score        KNN vs QDA  1.951164e-07           True
# 31       f1_score         KNN vs LR  1.903946e-10           True
# 32       f1_score     KNN vs Parzen  1.110223e-16           True
# 33       f1_score     KNN vs Voting  7.721867e-03           True
# 34       f1_score         QDA vs LR  8.080097e-01          False
# 35       f1_score     QDA vs Parzen  1.110223e-16           True
# 36       f1_score     QDA vs Voting  1.110223e-16           True
# 37       f1_score      LR vs Parzen  1.110223e-16           True
# 38       f1_score      LR vs Voting  1.110223e-16           True
# 39       f1_score  Parzen vs Voting  1.354472e-14           True

# %%
nemenyi_results.loc[nemenyi_results['are_different'] == False]
# Out:
#            metric   classifier_pair   p-value  are_different
# 3      error_rate     KNN vs Voting  0.914131          False
# 13  test_accuracy     KNN vs Voting  0.914131          False
# 29       coverage  Parzen vs Voting  0.297889          False
# 34       f1_score         QDA vs LR  0.808010          False
