# %% [markdown]
# # Statistical comparison of multiple classifiers
#
# Here, multiple classifiers were compared by using the results of a 30 x 10-fold cross-validation.
#
# They are compared when finetuning was employed or not.

# %%
import pandas as pd
import sys
import os
sys.path.append(os.path.abspath('../modules'))
from statistical_methods import StatisticalMethods

# %% [markdown]
# ## No finetuning

# %%
finetune = False

# %%
knn_results = pd.read_csv(f'../results/metrics_KNN_tuning_{finetune}.csv')
qda_results = pd.read_csv(f'../results/metrics_QDA_tuning_{finetune}.csv')
lr_results = pd.read_csv(f'../results/metrics_LR_tuning_{finetune}.csv')
parzen_results = pd.read_csv(f'../results/metrics_KDE_tuning_{finetune}.csv')
voting_results = pd.read_csv(f'../results/metrics_Voting_tuning_{finetune}.csv')

list_of_model_results = [knn_results, qda_results, lr_results, parzen_results, voting_results]
list_of_model_names = ['KNN', 'QDA', 'LR', 'KDE', 'Voting']
list_of_metrics_names = ['error_rate', 'test_accuracy', 'coverage', 'f1_score']

comp = StatisticalMethods(list_of_model_results, list_of_model_names, list_of_metrics_names)

friedman_results, metrics_with_difference = comp.friedman_test()

nemenyi_results = comp.nemenyi_test(metrics_with_difference)

# %%
comp.get_estimate_and_ci()
# Out:
#      model         metric      mean       std              ci
# 0      KNN     error_rate  0.255076  0.069403  0.2472, 0.2629
# 1      KNN  test_accuracy  0.744924  0.069403  0.7371, 0.7528
# 2      KNN       coverage  0.852273  0.072687  0.8440, 0.8605
# 3      KNN       f1_score  0.840360  0.046899  0.8351, 0.8457
# 4      QDA     error_rate  0.206087  0.016807  0.2042, 0.2080
# 5      QDA  test_accuracy  0.793913  0.016807  0.7920, 0.7958
# 6      QDA       coverage  0.999690  0.003788  0.9993, 1.0001
# 7      QDA       f1_score  0.885021  0.010447  0.8838, 0.8862
# 8       LR     error_rate  0.244131  0.074624  0.2357, 0.2526
# 9       LR  test_accuracy  0.755869  0.074624  0.7474, 0.7643
# 10      LR       coverage  0.856999  0.081155  0.8478, 0.8662
# 11      LR       f1_score  0.846458  0.051537  0.8406, 0.8523
# 12     KDE     error_rate  0.243927  0.065555  0.2365, 0.2513
# 13     KDE  test_accuracy  0.756073  0.065555  0.7487, 0.7635
# 14     KDE       coverage  0.890000  0.068325  0.8823, 0.8977
# 15     KDE       f1_score  0.851971  0.042697  0.8471, 0.8568
# 16  Voting     error_rate  0.230133  0.060463  0.2233, 0.2370
# 17  Voting  test_accuracy  0.769867  0.060463  0.7630, 0.7767
# 18  Voting       coverage  0.902128  0.061363  0.8952, 0.9091
# 19  Voting       f1_score  0.861010  0.038495  0.8567, 0.8654

# %%
formatted_stats = comp.get_formatted_estimate_and_ci()
formatted_stats
# Out:
#     Modelo            Métrica     Média (%)            IC (%)
# 0      KNN       Taxa de erro  25.51 ± 6.94   [24.72 , 26.29]
# 1      KNN  Acurácia de teste  74.49 ± 6.94   [73.71 , 75.28]
# 2      KNN          Cobertura  85.23 ± 7.27   [84.40 , 86.05]
# 3      KNN           F1-score  84.04 ± 4.69   [83.51 , 84.57]
# 4      QDA       Taxa de erro  20.61 ± 1.68   [20.42 , 20.80]
# 5      QDA  Acurácia de teste  79.39 ± 1.68   [79.20 , 79.58]
# 6      QDA          Cobertura  99.97 ± 0.38  [99.93 , 100.01]
# 7      QDA           F1-score  88.50 ± 1.04   [88.38 , 88.62]
# 8       LR       Taxa de erro  24.41 ± 7.46   [23.57 , 25.26]
# 9       LR  Acurácia de teste  75.59 ± 7.46   [74.74 , 76.43]
# 10      LR          Cobertura  85.70 ± 8.12   [84.78 , 86.62]
# 11      LR           F1-score  84.65 ± 5.15   [84.06 , 85.23]
# 12     KDE       Taxa de erro  24.39 ± 6.56   [23.65 , 25.13]
# 13     KDE  Acurácia de teste  75.61 ± 6.56   [74.87 , 76.35]
# 14     KDE          Cobertura  89.00 ± 6.83   [88.23 , 89.77]
# 15     KDE           F1-score  85.20 ± 4.27   [84.71 , 85.68]
# 16  Voting       Taxa de erro  23.01 ± 6.05   [22.33 , 23.70]
# 17  Voting  Acurácia de teste  76.99 ± 6.05   [76.30 , 77.67]
# 18  Voting          Cobertura  90.21 ± 6.14   [89.52 , 90.91]
# 19  Voting           F1-score  86.10 ± 3.85   [85.67 , 86.54]

# %%
friedman_results
# Out:
#           metric   statistic        p-value  are_different
# 0     error_rate  132.685406   1.037578e-27           True
# 1  test_accuracy  132.685406   1.037578e-27           True
# 2       coverage  680.172369  6.844013e-146           True
# 3       f1_score  253.798070   9.892739e-54           True

# %%
nemenyi_results
# Out:
#            metric classifier_pair       p-value  are_different
# 0      error_rate      KNN vs QDA  1.110223e-16           True
# 1      error_rate       KNN vs LR  5.420539e-02          False
# 2      error_rate      KNN vs KDE  1.767582e-01          False
# 3      error_rate   KNN vs Voting  2.242431e-06           True
# 4      error_rate       QDA vs LR  4.845124e-12           True
# 5      error_rate      QDA vs KDE  1.163514e-13           True
# 6      error_rate   QDA vs Voting  1.999012e-05           True
# 7      error_rate       LR vs KDE  9.882599e-01          False
# 8      error_rate    LR vs Voting  9.544077e-02          False
# 9      error_rate   KDE vs Voting  2.488351e-02           True
# 10  test_accuracy      KNN vs QDA  1.110223e-16           True
# 11  test_accuracy       KNN vs LR  5.420539e-02          False
# 12  test_accuracy      KNN vs KDE  1.767582e-01          False
# 13  test_accuracy   KNN vs Voting  2.242431e-06           True
# 14  test_accuracy       QDA vs LR  4.845124e-12           True
# 15  test_accuracy      QDA vs KDE  1.163514e-13           True
# 16  test_accuracy   QDA vs Voting  1.999012e-05           True
# 17  test_accuracy       LR vs KDE  9.882599e-01          False
# 18  test_accuracy    LR vs Voting  9.544077e-02          False
# 19  test_accuracy   KDE vs Voting  2.488351e-02           True
# 20       coverage      KNN vs QDA  1.110223e-16           True
# 21       coverage       KNN vs LR  6.062325e-01          False
# 22       coverage      KNN vs KDE  9.177740e-08           True
# 23       coverage   KNN vs Voting  1.110223e-16           True
# 24       coverage       QDA vs LR  1.110223e-16           True
# 25       coverage      QDA vs KDE  1.110223e-16           True
# 26       coverage   QDA vs Voting  1.110223e-16           True
# 27       coverage       LR vs KDE  1.574634e-04           True
# 28       coverage    LR vs Voting  6.439071e-12           True
# 29       coverage   KDE vs Voting  3.256853e-02           True
# 30       f1_score      KNN vs QDA  1.110223e-16           True
# 31       f1_score       KNN vs LR  4.539020e-02           True
# 32       f1_score      KNN vs KDE  5.380791e-03           True
# 33       f1_score   KNN vs Voting  1.220618e-10           True
# 34       f1_score       QDA vs LR  1.110223e-16           True
# 35       f1_score      QDA vs KDE  1.110223e-16           True
# 36       f1_score   QDA vs Voting  2.600142e-13           True
# 37       f1_score       LR vs KDE  9.625830e-01          False
# 38       f1_score    LR vs Voting  5.691423e-04           True
# 39       f1_score   KDE vs Voting  7.385715e-03           True

# %%
nemenyi_results.loc[nemenyi_results['are_different'] == False]
# Out:
#            metric classifier_pair   p-value  are_different
# 1      error_rate       KNN vs LR  0.054205          False
# 2      error_rate      KNN vs KDE  0.176758          False
# 7      error_rate       LR vs KDE  0.988260          False
# 8      error_rate    LR vs Voting  0.095441          False
# 11  test_accuracy       KNN vs LR  0.054205          False
# 12  test_accuracy      KNN vs KDE  0.176758          False
# 17  test_accuracy       LR vs KDE  0.988260          False
# 18  test_accuracy    LR vs Voting  0.095441          False
# 21       coverage       KNN vs LR  0.606232          False
# 37       f1_score       LR vs KDE  0.962583          False

# %% [markdown]
# ## With finetuning

# %%
finetune = True

# %%
knn_results = pd.read_csv(f'../results/metrics_KNN_tuning_{finetune}.csv')
qda_results = pd.read_csv(f'../results/metrics_QDA_tuning_{finetune}.csv')
lr_results = pd.read_csv(f'../results/metrics_LR_tuning_{finetune}.csv')
parzen_results = pd.read_csv(f'../results/metrics_KDE_tuning_{finetune}.csv')
voting_results = pd.read_csv(f'../results/metrics_Voting_tuning_{finetune}.csv')

list_of_model_results = [knn_results, qda_results, lr_results, parzen_results, voting_results]
list_of_model_names = ['KNN', 'QDA', 'LR', 'KDE', 'Voting']
list_of_metrics_names = ['error_rate', 'test_accuracy', 'coverage', 'f1_score']

comp = StatisticalMethods(list_of_model_results, list_of_model_names, list_of_metrics_names)

friedman_results, metrics_with_difference = comp.friedman_test()

nemenyi_results = comp.nemenyi_test(metrics_with_difference)

# %%
comp.get_estimate_and_ci()
# Out:
#      model         metric      mean       std              ci
# 0      KNN     error_rate  0.234473  0.072668  0.2262, 0.2427
# 1      KNN  test_accuracy  0.765527  0.072668  0.7573, 0.7738
# 2      KNN       coverage  0.863680  0.074616  0.8552, 0.8721
# 3      KNN       f1_score  0.852917  0.048964  0.8474, 0.8585
# 4      QDA     error_rate  0.219767  0.046709  0.2145, 0.2251
# 5      QDA  test_accuracy  0.780233  0.046709  0.7749, 0.7855
# 6      QDA       coverage  0.953810  0.114889  0.9408, 0.9668
# 7      QDA       f1_score  0.870012  0.044593  0.8650, 0.8751
# 8       LR     error_rate  0.199525  0.068187  0.1918, 0.2072
# 9       LR  test_accuracy  0.800475  0.068187  0.7928, 0.8082
# 10      LR       coverage  0.881623  0.069513  0.8738, 0.8895
# 11      LR       f1_score  0.874402  0.045279  0.8693, 0.8795
# 12     KDE     error_rate  0.306377  0.086308  0.2966, 0.3161
# 13     KDE  test_accuracy  0.693623  0.086308  0.6839, 0.7034
# 14     KDE       coverage  0.738146  0.106577  0.7261, 0.7502
# 15     KDE       f1_score  0.789173  0.070536  0.7812, 0.7972
# 16  Voting     error_rate  0.242217  0.083112  0.2328, 0.2516
# 17  Voting  test_accuracy  0.757783  0.083112  0.7484, 0.7672
# 18  Voting       coverage  0.783066  0.098162  0.7720, 0.7942
# 19  Voting       f1_score  0.834221  0.063693  0.8270, 0.8414

# %%
formatted_stats = comp.get_formatted_estimate_and_ci()
formatted_stats
# Out:
#     Modelo            Métrica      Média (%)           IC (%)
# 0      KNN       Taxa de erro   23.45 ± 7.27  [22.62 , 24.27]
# 1      KNN  Acurácia de teste   76.55 ± 7.27  [75.73 , 77.38]
# 2      KNN          Cobertura   86.37 ± 7.46  [85.52 , 87.21]
# 3      KNN           F1-score   85.29 ± 4.90  [84.74 , 85.85]
# 4      QDA       Taxa de erro   21.98 ± 4.67  [21.45 , 22.51]
# 5      QDA  Acurácia de teste   78.02 ± 4.67  [77.49 , 78.55]
# 6      QDA          Cobertura  95.38 ± 11.49  [94.08 , 96.68]
# 7      QDA           F1-score   87.00 ± 4.46  [86.50 , 87.51]
# 8       LR       Taxa de erro   19.95 ± 6.82  [19.18 , 20.72]
# 9       LR  Acurácia de teste   80.05 ± 6.82  [79.28 , 80.82]
# 10      LR          Cobertura   88.16 ± 6.95  [87.38 , 88.95]
# 11      LR           F1-score   87.44 ± 4.53  [86.93 , 87.95]
# 12     KDE       Taxa de erro   30.64 ± 8.63  [29.66 , 31.61]
# 13     KDE  Acurácia de teste   69.36 ± 8.63  [68.39 , 70.34]
# 14     KDE          Cobertura  73.81 ± 10.66  [72.61 , 75.02]
# 15     KDE           F1-score   78.92 ± 7.05  [78.12 , 79.72]
# 16  Voting       Taxa de erro   24.22 ± 8.31  [23.28 , 25.16]
# 17  Voting  Acurácia de teste   75.78 ± 8.31  [74.84 , 76.72]
# 18  Voting          Cobertura   78.31 ± 9.82  [77.20 , 79.42]
# 19  Voting           F1-score   83.42 ± 6.37  [82.70 , 84.14]

# %%
friedman_results
# Out:
#           metric   statistic        p-value  are_different
# 0     error_rate  321.684443   2.270924e-68           True
# 1  test_accuracy  321.684443   2.270924e-68           True
# 2       coverage  679.374867  1.018540e-145           True
# 3       f1_score  392.276211   1.297399e-83           True

# %%
nemenyi_results
# Out:
#            metric classifier_pair       p-value  are_different
# 0      error_rate      KNN vs QDA  1.114551e-01          False
# 1      error_rate       KNN vs LR  9.904020e-08           True
# 2      error_rate      KNN vs KDE  1.110223e-16           True
# 3      error_rate   KNN vs Voting  4.154244e-01          False
# 4      error_rate       QDA vs LR  8.071825e-03           True
# 5      error_rate      QDA vs KDE  1.110223e-16           True
# 6      error_rate   QDA vs Voting  3.291866e-04           True
# 7      error_rate       LR vs KDE  1.110223e-16           True
# 8      error_rate    LR vs Voting  8.525403e-13           True
# 9      error_rate   KDE vs Voting  1.110223e-16           True
# 10  test_accuracy      KNN vs QDA  1.114551e-01          False
# 11  test_accuracy       KNN vs LR  9.904020e-08           True
# 12  test_accuracy      KNN vs KDE  1.110223e-16           True
# 13  test_accuracy   KNN vs Voting  4.154244e-01          False
# 14  test_accuracy       QDA vs LR  8.071825e-03           True
# 15  test_accuracy      QDA vs KDE  1.110223e-16           True
# 16  test_accuracy   QDA vs Voting  3.291866e-04           True
# 17  test_accuracy       LR vs KDE  1.110223e-16           True
# 18  test_accuracy    LR vs Voting  8.525403e-13           True
# 19  test_accuracy   KDE vs Voting  1.110223e-16           True
# 20       coverage      KNN vs QDA  1.110223e-16           True
# 21       coverage       KNN vs LR  2.351306e-01          False
# 22       coverage      KNN vs KDE  1.110223e-16           True
# 23       coverage   KNN vs Voting  1.110223e-16           True
# 24       coverage       QDA vs LR  9.330015e-11           True
# 25       coverage      QDA vs KDE  1.110223e-16           True
# 26       coverage   QDA vs Voting  1.110223e-16           True
# 27       coverage       LR vs KDE  1.110223e-16           True
# 28       coverage    LR vs Voting  1.110223e-16           True
# 29       coverage   KDE vs Voting  4.267908e-03           True
# 30       f1_score      KNN vs QDA  1.486023e-04           True
# 31       f1_score       KNN vs LR  1.115296e-06           True
# 32       f1_score      KNN vs KDE  1.110223e-16           True
# 33       f1_score   KNN vs Voting  2.783877e-04           True
# 34       f1_score       QDA vs LR  8.638811e-01          False
# 35       f1_score      QDA vs KDE  1.110223e-16           True
# 36       f1_score   QDA vs Voting  3.330669e-16           True
# 37       f1_score       LR vs KDE  1.110223e-16           True
# 38       f1_score    LR vs Voting  1.110223e-16           True
# 39       f1_score   KDE vs Voting  5.212497e-13           True

# %%
nemenyi_results.loc[nemenyi_results['are_different'] == False]
# Out:
#            metric classifier_pair   p-value  are_different
# 0      error_rate      KNN vs QDA  0.111455          False
# 3      error_rate   KNN vs Voting  0.415424          False
# 10  test_accuracy      KNN vs QDA  0.111455          False
# 13  test_accuracy   KNN vs Voting  0.415424          False
# 21       coverage       KNN vs LR  0.235131          False
# 34       f1_score       QDA vs LR  0.863881          False
